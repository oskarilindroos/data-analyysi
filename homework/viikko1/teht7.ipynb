# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('./work/viikko1/datasets/diabetes.csv')

# %%
desc = df.describe()
plt.show()

# %%
df.hist()
plt.show()

# %%
corr = df.corr()
sb.heatmap(corr, annot=True, cbar=False)
plt.show()

# %%
ageGroup = df['Age'].value_counts()

# %%
diabetesCount = df['Outcome'].value_counts()

# %%
nullCount = df.isna().sum()
