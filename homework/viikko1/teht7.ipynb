# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('./work/viikko1/diabetes.csv')

# %%
desc = df.describe()

df[['Pregnancies', 'Glucose', 'BloodPressure']].hist()
plt.show()

corr = df.corr()

diabetes = df['Outcome'].value_counts()

sb.heatmap(corr, annot=True, cbar=False)
plt.show()
